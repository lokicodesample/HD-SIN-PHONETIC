# %%
# Train on 5% data, Split 1
python architecture_a.py --config 5percent --split 1 --epochs 10 --batch_size 64 --auto_resume

# Train on 5% data, Split 2 (open-set)
python architecture_a.py --config 5percent --split 2 --epochs 10 --batch_size 64 --auto_resume

# %%
# !python architecture_a.py --config 5percent --split 1 --epochs 10 --batch_size 32 --auto_resume
# Out:
# ...
# 🎯 ARCHITECTURE A: Classifier Fine-tuning
# ...
# Dataset: 5percent
# Split: 1
# Batch size: 32
# Epochs: 10
# Auto-resume: True
#
# 📂 Loading datasets...
# 📊 Dataset loaded: 62521 files, 9477 speakers
# 📊 Dataset loaded: 13561 files, 5973 speakers
# 🔄 Loading WavLM-large (frozen)...
# Loading weights: 100%|█| 488/488 [00:00<00:00, 14197.17it/s, Materializing param
# ✅ Architecture A: 5,386,525 trainable params
# 📂 Found checkpoint: checkpoints/architecture_a_split1_checkpoint.pt
# ✅ Resumed from epoch 9
# ...
# Epoch 10/10 [Val]: 100%|██████████████████████| 424/424 [02:07<00:00,  3.32it/s]
#
# Epoch 10: Train Acc: 64.66%, Val Acc: 0.00%
#
# ✅ Training complete! Best accuracy: 0.05%

# %%
# !python Evaluate_Classifier.py --config 5percent --split 1 --checkpoint checkpoints/architecture_a_split1_best.pt
# Out:
# ...
# 📊 EVALUATING ARCHITECTURE A
# ...
# Dataset: 5percent
# Split: 1
# Checkpoint: checkpoints/architecture_a_split1_best.pt
#
# 📂 Loading test dataset...
#    Model expects 9477 speakers
#
# 🔧 Loading model...
# 🔄 Loading WavLM-large (frozen)...
# Loading weights: 100%|█| 488/488 [00:00<00:00, 13647.11it/s, Materializing param
# ✅ Architecture A: 5,386,525 trainable params
#    Loaded model weights
#
# 🔍 Extracting embeddings...
# Extracting: 100%|█████████████████████████████| 437/437 [06:07<00:00,  1.19it/s]
# ✅ Extracted 13983 embeddings, dim=9477
#    Unique speakers in test: 6171
#
# 📊 Creating evaluation trials...
#    Genuine trials: 43054
#    Impostor trials: 50000
#
# 📈 RESULTS:
# ...
#    EER: 32.80%
#    AUC: 0.7384
#    Genuine scores mean: 0.7720
#    Impostor scores mean: 0.5813
# ...
#
# ✅ Results saved to: results_a_split1.txt

# %%
# !python architecture_a.py --config 5percent --split 2 --epochs 10 --batch_size 32
# Out:
# ...
# 🎯 ARCHITECTURE A: Classifier Fine-tuning
# ...
# Dataset: 5percent
# Split: 2
# Batch size: 32
# Epochs: 10
# Auto-resume: False
#
# 📂 Loading datasets...
# 📊 Dataset loaded: 73215 files, 8194 speakers
# 📊 Dataset loaded: 10038 files, 1020 speakers
# 🔄 Loading WavLM-large (frozen)...
# Loading weights: 100%|█| 488/488 [00:00<00:00, 14216.70it/s, Materializing param
# ✅ Architecture A: 4,728,346 trainable params
# Epoch 1/10 [Train]:  68%|████  | 1557/2288 [20:48<09:38,  1.26it/s, loss=7.0317]

# %%
# Architecture A
python evaluate_a.py --config 5percent --split 1 --checkpoint checkpoints/architecture_a_split1_best.pt
python evaluate_a.py --config 5percent --split 2 --checkpoint checkpoints/architecture_a_split2_best.pt

# %%
# Train on 5% data, Split 2 (open-set)
# !python architecture_a.py --config 5percent --split 2 --epochs 10 --batch_size 32
# Out:
# ...
# 🎯 ARCHITECTURE A: Classifier Fine-tuning
# ...
# Dataset: 5percent
# Split: 2
# Batch size: 32
# Epochs: 10
# Auto-resume: False
#
# 📂 Loading datasets...
# 📊 Dataset loaded: 73215 files, 8194 speakers
# 📊 Dataset loaded: 10038 files, 1020 speakers
# 🔄 Loading WavLM-large (frozen)...
# ^C
#
#
# ⚠️  Interrupt received! Saving checkpoint before exit...

# %%
# !python Evaluate_Classifier.py --config 5percent --split 2 --checkpoint checkpoints/architecture_a_split1_best.pt
# Out:
# ...
# 📊 EVALUATING ARCHITECTURE A
# ...
# Dataset: 5percent
# Split: 2
# Checkpoint: checkpoints/architecture_a_split1_best.pt
#
# 📂 Loading test dataset...
#    Model expects 9477 speakers
#
# 🔧 Loading model...
# 🔄 Loading WavLM-large (frozen)...
# Loading weights: 100%|█| 488/488 [00:00<00:00, 13528.67it/s, Materializing param
# ✅ Architecture A: 5,386,525 trainable params
#    Loaded model weights
#
# 🔍 Extracting embeddings...
# Extracting: 100%|█████████████████████████████| 271/271 [03:53<00:00,  1.16it/s]
# ✅ Extracted 8662 embeddings, dim=9477
#    Unique speakers in test: 1019
#
# 📊 Creating evaluation trials...
#    Genuine trials: 45006
#    Impostor trials: 50000
#
# 📈 RESULTS:
# ...
#    EER: 27.93%
#    AUC: 0.7966
#    Genuine scores mean: 0.8022
#    Impostor scores mean: 0.5613
# ...
#
# ✅ Results saved to: results_a_split2.txt

# %%
# !python Evaluate_Classifier.py --config 5percent --split 1 --checkpoint checkpoints/architecture_a_split1_best.pt
# Out:
# ...
# 📊 EVALUATING WAVLM + CLASSIFIER (Architecture A)
# ...
# Dataset: 5percent
# Split: 1 (Identification)
# Checkpoint: checkpoints/architecture_a_split1_best.pt
# Batch size: 32
#
# 📂 Loading test dataset...
#    Loaded 13983 files
#    Model expects 9477 speakers
#
# 🔧 Loading model...
# 🔄 Loading WavLM-large (frozen)...
# Loading weights: 100%|█| 488/488 [00:00<00:00, 14288.45it/s, Materializing param
# ✅ Architecture A: 5,386,525 trainable params
#    Loaded model weights
#
# 🔍 Extracting embeddings...
# Extracting: 100%|█████████████████████████████| 437/437 [06:14<00:00,  1.17it/s]
# ✅ Extracted 13983 embeddings, dim=9477
#    Unique speakers: 6171
#    Languages: {'english', 'tamil', 'telugu'}
#
# 📊 Creating evaluation trials...
#    Genuine trials: 91251
#    Creating impostor trials: 100%|█████| 50000/50000 [00:03<00:00, 14009.12it/s]
#    Impostor trials: 50000
#
# 📈 OVERALL RESULTS:
# ...
#    EER: 31.30%
#    AUC: 0.7552
#    Genuine mean: 0.7866 ± 0.2501
# ...

# %%
# !python Evaluate_Classifier.py --config 5percent --split 2 --checkpoint checkpoints/architecture_a_split1_best.pt
# Out:
# ...
# 📊 EVALUATING WAVLM + CLASSIFIER (Architecture A)
# ...
# Dataset: 5percent
# Split: 2 (Open-set)
# Checkpoint: checkpoints/architecture_a_split1_best.pt
# Batch size: 32
#
# 📂 Loading test dataset...
#    Loaded 8662 files
#    Model expects 9477 speakers
#
# 🔧 Loading model...
# 🔄 Loading WavLM-large (frozen)...
# Loading weights: 100%|█| 488/488 [00:00<00:00, 13798.08it/s, Materializing param
# ✅ Architecture A: 5,386,525 trainable params
#    Loaded model weights
#
# 🔍 Extracting embeddings...
# Extracting: 100%|█████████████████████████████| 271/271 [03:51<00:00,  1.17it/s]
# ✅ Extracted 8662 embeddings, dim=9477
#    Unique speakers: 1019
#    Languages: {'tamil', 'english', 'telugu'}
#
# 📊 Creating evaluation trials...
#    Genuine trials: 64315
#    Creating impostor trials: 100%|█████| 50000/50000 [00:01<00:00, 28742.03it/s]
#    Impostor trials: 50000
#
# 📈 OVERALL RESULTS:
# ...
#    EER: 29.29%
#    AUC: 0.7809
#    Genuine mean: 0.7901 ± 0.1970
#    Impostor mean: 0.5611 ± 0.2346
# ...
#
# ...
