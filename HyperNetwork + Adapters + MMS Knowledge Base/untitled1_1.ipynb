# %%
# !python evaluate_baseline.py --config 5percent --split 1 --model ecapa
# Out:
# /home/ladmin/anaconda3/envs/asr_sii/lib/python3.10/site-packages/torch/backends/__init__.py:46: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   self.setter(val)
#
# ======================================================================
# 📊 EVALUATING BASELINE: ECAPA
# ======================================================================
# Dataset: 5percent
# Split: 1 (Identification)
# Model: ECAPA
# Batch size: 32
# Max trials: 50000
#
# 📂 Loading test dataset...
# 📊 HD-SIN Dataset: 13983 files
#    Speakers: 6171
#    Languages: {'english', 'tamil', 'telugu'}
#
# 🔧 Loading model...
#    Device: cuda:0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#    Model loaded, embedding dimension: 192
#
# 🔍 Extracting embeddings...
# Extracting embeddings: 100%|██████████████████| 437/437 [00:29<00:00, 15.05it/s]
#
# ✅ Extracted 13983 embeddings, dim=192
#
# 📊 Grouping by speaker...
#    Unique speakers: 6171
#
# 📊 Creating evaluation trials...
#    Creating genuine trials...
#    Genuine trials: 91251
#    Creating impostor trials...
#    Creating impostor trials: 100%|█████| 50000/50000 [00:03<00:00, 15042.81it/s]
#    Impostor trials: 50000
#
# 📊 Computing results...
#
# ======================================================================
# 📈 ECAPA-TDNN RESULTS
# ======================================================================
#
# =================Overall Results==================
# Equal Error Rate (EER): 9.70%
# Area Under Curve (AUC): 0.9611
# Threshold at EER: 0.3281
#
# Genuine scores: mean=0.5494 ± 0.1583
# Impostor scores: mean=0.1663 ± 0.1171
# Genuine trials: 91251
# Impostor trials: 50000
#
# ===============Per-Language Results===============
#
# Tamil:
#   EER: 13.71%
#   AUC: 0.9363
#   Genuine mean: 0.5313
#   Impostor mean: 0.2071
#   Trials: genuine=3974, impostor=10000
#
# Telugu:
#   EER: 11.04%
#   AUC: 0.9524
#   Genuine mean: 0.5721
#   Impostor mean: 0.1809
#   Trials: genuine=1967, impostor=10000
#
# English:
#   EER: 9.67%
#   AUC: 0.9592
#   Genuine mean: 0.5434
#   Impostor mean: 0.1666
#   Trials: genuine=37113, impostor=10000
#
# ✅ Results saved to: ./ecapa_split1_results.txt
#
# 📊 Generating plots...
# ✅ Plot saved to: ./ecapa_split1_results.png
#
# ======================================================================
# 📊 FINAL SUMMARY
# ======================================================================
# Model: ECAPA
# Split: 1
# EER: 9.70%
# AUC: 0.9611

# %%
# !python evaluate_baseline.py --config 5percent --split 1 --model xvector
# Out:
# /home/ladmin/anaconda3/envs/asr_sii/lib/python3.10/site-packages/torch/backends/__init__.py:46: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   self.setter(val)
#
# ======================================================================
# 📊 EVALUATING BASELINE: XVECTOR
# ======================================================================
# Dataset: 5percent
# Split: 1 (Identification)
# Model: XVECTOR
# Batch size: 32
# Max trials: 50000
#
# 📂 Loading test dataset...
# 📊 HD-SIN Dataset: 13983 files
#    Speakers: 6171
#    Languages: {'english', 'telugu', 'tamil'}
#
# 🔧 Loading model...
#    Device: cuda:0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#    Model loaded, embedding dimension: 512
#
# 🔍 Extracting embeddings...
# Extracting embeddings: 100%|█████████████████| 437/437 [00:04<00:00, 102.06it/s]
#
# ✅ Extracted 13983 embeddings, dim=512
#
# 📊 Grouping by speaker...
#    Unique speakers: 6171
#
# 📊 Creating evaluation trials...
#    Creating genuine trials...
#    Genuine trials: 91251
#    Creating impostor trials...
#    Creating impostor trials: 100%|█████| 50000/50000 [00:03<00:00, 15588.01it/s]
#    Impostor trials: 50000
#
# 📊 Computing results...
#
# ======================================================================
# 📈 X-Vector RESULTS
# ======================================================================
#
# =================Overall Results==================
# Equal Error Rate (EER): 30.06%
# Area Under Curve (AUC): 0.7820
# Threshold at EER: 0.9343
#
# Genuine scores: mean=0.9401 ± 0.0441
# Impostor scores: mean=0.8799 ± 0.0770
# Genuine trials: 91251
# Impostor trials: 50000
#
# ===============Per-Language Results===============
#
# Tamil:
#   EER: 24.27%
#   AUC: 0.8148
#   Genuine mean: 0.9570
#   Impostor mean: 0.9238
#   Trials: genuine=3974, impostor=10000
#
# Telugu:
#   EER: 26.15%
#   AUC: 0.8200
#   Genuine mean: 0.9363
#   Impostor mean: 0.8637
#   Trials: genuine=1967, impostor=10000
#
# English:
#   EER: 30.94%
#   AUC: 0.7602
#   Genuine mean: 0.9397
#   Impostor mean: 0.9010
#   Trials: genuine=37113, impostor=10000
#
# ✅ Results saved to: ./xvector_split1_results.txt
#
# 📊 Generating plots...
# ✅ Plot saved to: ./xvector_split1_results.png
#
# ======================================================================
# 📊 FINAL SUMMARY
# ======================================================================
# Model: XVECTOR
# Split: 1
# EER: 30.06%
# AUC: 0.7820

# %%
# !python evaluate_baseline.py --config 5percent --split 2 --model ecapa
# Out:
# /home/ladmin/anaconda3/envs/asr_sii/lib/python3.10/site-packages/torch/backends/__init__.py:46: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   self.setter(val)
#
# ======================================================================
# 📊 EVALUATING BASELINE: ECAPA
# ======================================================================
# Dataset: 5percent
# Split: 2 (Open-set)
# Model: ECAPA
# Batch size: 32
# Max trials: 50000
#
# 📂 Loading test dataset...
# 📊 HD-SIN Dataset: 8662 files
#    Speakers: 1019
#    Languages: {'tamil', 'telugu', 'english'}
#
# 🔧 Loading model...
#    Device: cuda:0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#    Model loaded, embedding dimension: 192
#
# 🔍 Extracting embeddings...
# Extracting embeddings: 100%|██████████████████| 271/271 [00:17<00:00, 15.12it/s]
#
# ✅ Extracted 8662 embeddings, dim=192
#
# 📊 Grouping by speaker...
#    Unique speakers: 1019
#
# 📊 Creating evaluation trials...
#    Creating genuine trials...
#    Genuine trials: 64315
#    Creating impostor trials...
#    Creating impostor trials: 100%|█████| 50000/50000 [00:01<00:00, 37108.11it/s]
#    Impostor trials: 50000
#
# 📊 Computing results...
#
# ======================================================================
# 📈 ECAPA-TDNN RESULTS
# ======================================================================
#
# =================Overall Results==================
# Equal Error Rate (EER): 8.83%
# Area Under Curve (AUC): 0.9664
# Threshold at EER: 0.3293
#
# Genuine scores: mean=0.5617 ± 0.1569
# Impostor scores: mean=0.1620 ± 0.1163
# Genuine trials: 64315
# Impostor trials: 50000
#
# ===============Per-Language Results===============
#
# Tamil:
#   EER: 13.46%
#   AUC: 0.9348
#   Genuine mean: 0.5443
#   Impostor mean: 0.2139
#   Trials: genuine=17112, impostor=6540
#
# Telugu:
#   EER: 10.84%
#   AUC: 0.9548
#   Genuine mean: 0.5645
#   Impostor mean: 0.1760
#   Trials: genuine=9492, impostor=9980
#
# English:
#   EER: 7.88%
#   AUC: 0.9697
#   Genuine mean: 0.5716
#   Impostor mean: 0.1685
#   Trials: genuine=18402, impostor=3860
#
# ✅ Results saved to: ./ecapa_split2_results.txt
#
# 📊 Generating plots...
# ✅ Plot saved to: ./ecapa_split2_results.png
#
# ======================================================================
# 📊 FINAL SUMMARY
# ======================================================================
# Model: ECAPA
# Split: 2
# EER: 8.83%
# AUC: 0.9664

# %%
# !python evaluate_baseline.py --config 5percent --split 2 --model xvector
# Out:
# /home/ladmin/anaconda3/envs/asr_sii/lib/python3.10/site-packages/torch/backends/__init__.py:46: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   self.setter(val)
#
# ======================================================================
# 📊 EVALUATING BASELINE: XVECTOR
# ======================================================================
# Dataset: 5percent
# Split: 2 (Open-set)
# Model: XVECTOR
# Batch size: 32
# Max trials: 50000
#
# 📂 Loading test dataset...
# 📊 HD-SIN Dataset: 8662 files
#    Speakers: 1019
#    Languages: {'telugu', 'english', 'tamil'}
#
# 🔧 Loading model...
#    Device: cuda:0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#    Model loaded, embedding dimension: 512
#
# 🔍 Extracting embeddings...
# Extracting embeddings: 100%|██████████████████| 271/271 [00:02<00:00, 97.09it/s]
#
# ✅ Extracted 8662 embeddings, dim=512
#
# 📊 Grouping by speaker...
#    Unique speakers: 1019
#
# 📊 Creating evaluation trials...
#    Creating genuine trials...
#    Genuine trials: 64315
#    Creating impostor trials...
#    Creating impostor trials: 100%|█████| 50000/50000 [00:01<00:00, 34956.12it/s]
#    Impostor trials: 50000
#
# 📊 Computing results...
#
# ======================================================================
# 📈 X-Vector RESULTS
# ======================================================================
#
# =================Overall Results==================
# Equal Error Rate (EER): 25.80%
# Area Under Curve (AUC): 0.8317
# Threshold at EER: 0.9337
#
# Genuine scores: mean=0.9451 ± 0.0485
# Impostor scores: mean=0.8708 ± 0.0784
# Genuine trials: 64315
# Impostor trials: 50000
#
# ===============Per-Language Results===============
#
# Tamil:
#   EER: 21.90%
#   AUC: 0.8399
#   Genuine mean: 0.9606
#   Impostor mean: 0.9186
#   Trials: genuine=17112, impostor=6540
#
# Telugu:
#   EER: 27.18%
#   AUC: 0.8133
#   Genuine mean: 0.9331
#   Impostor mean: 0.8593
#   Trials: genuine=9492, impostor=9980
#
# English:
#   EER: 29.22%
#   AUC: 0.7875
#   Genuine mean: 0.9436
#   Impostor mean: 0.8976
#   Trials: genuine=18402, impostor=3860
#
# ✅ Results saved to: ./xvector_split2_results.txt
#
# 📊 Generating plots...
# ✅ Plot saved to: ./xvector_split2_results.png
#
# ======================================================================
# 📊 FINAL SUMMARY
# ======================================================================
# Model: XVECTOR
# Split: 2
# EER: 25.80%
# AUC: 0.8317
