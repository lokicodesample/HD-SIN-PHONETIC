# %%
# !python evaluate_baseline.py --config 5percent --split 1 --model ecapa
# Out:
# /home/ladmin/anaconda3/envs/asr_sii/lib/python3.10/site-packages/torch/backends/__init__.py:46: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   self.setter(val)
#
# ============================================================
# 📊 EVALUATING BASELINE: ECAPA
# ============================================================
# 📊 HD-SIN Dataset: 13983 files
#    Speakers: 6171
#    Languages: {'tamil', 'telugu', 'english'}
#
# 🔧 Loading ECAPA baseline...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# 🔍 Extracting embeddings...
# Extracting embeddings: 100%|██████████████████| 874/874 [00:30<00:00, 28.97it/s]
# Extracted 13983 embeddings, dim=192
# Creating impostor trials: 100%|████████| 50000/50000 [00:03<00:00, 16375.78it/s]
#
# ============================================================
# 📈 BASELINE (ECAPA) RESULTS
# ============================================================
# Overall EER: 9.72%
#
# --- Per-Language EER ---
# Tamil EER: 14.00%
# Telugu EER: 11.16%
# English EER: 9.68%
# ============================================================

# %%
# !python evaluate_baseline.py --config 5percent --split 1 --model xvector
# Out:
# /home/ladmin/anaconda3/envs/asr_sii/lib/python3.10/site-packages/torch/backends/__init__.py:46: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   self.setter(val)
#
# ============================================================
# 📊 EVALUATING BASELINE: XVECTOR
# ============================================================
# 📊 HD-SIN Dataset: 13983 files
#    Speakers: 6171
#    Languages: {'english', 'telugu', 'tamil'}
#
# 🔧 Loading XVECTOR baseline...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# 🔍 Extracting embeddings...
# Extracting embeddings: 100%|█████████████████| 874/874 [00:05<00:00, 158.49it/s]
# Extracted 13983 embeddings, dim=512
# Creating impostor trials: 100%|████████| 50000/50000 [00:03<00:00, 16266.28it/s]
#
# ============================================================
# 📈 BASELINE (XVECTOR) RESULTS
# ============================================================
# Overall EER: 29.94%
#
# --- Per-Language EER ---
# Tamil EER: 24.37%
# Telugu EER: 25.88%
# English EER: 30.69%
# ============================================================

# %%
# !python evaluate_baseline.py --config 5percent --split 2 --model ecapa
# Out:
# /home/ladmin/anaconda3/envs/asr_sii/lib/python3.10/site-packages/torch/backends/__init__.py:46: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   self.setter(val)
#
# ============================================================
# 📊 EVALUATING BASELINE: ECAPA
# ============================================================
# 📊 HD-SIN Dataset: 8662 files
#    Speakers: 1019
#    Languages: {'telugu', 'english', 'tamil'}
#
# 🔧 Loading ECAPA baseline...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# 🔍 Extracting embeddings...
# Extracting embeddings: 100%|██████████████████| 542/542 [00:19<00:00, 28.49it/s]
# Extracted 8662 embeddings, dim=192
# Creating impostor trials: 100%|████████| 20380/20380 [00:00<00:00, 37480.62it/s]
#
# ============================================================
# 📈 BASELINE (ECAPA) RESULTS
# ============================================================
# Overall EER: 8.81%
#
# --- Per-Language EER ---
# Tamil EER: 13.64%
# Telugu EER: 10.75%
# English EER: 7.80%
# ============================================================

# %%
# !python evaluate_baseline.py --config 5percent --split 2 --model xvector
# Out:
# /home/ladmin/anaconda3/envs/asr_sii/lib/python3.10/site-packages/torch/backends/__init__.py:46: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   self.setter(val)
#
# ============================================================
# 📊 EVALUATING BASELINE: XVECTOR
# ============================================================
# 📊 HD-SIN Dataset: 8662 files
#    Speakers: 1019
#    Languages: {'english', 'telugu', 'tamil'}
#
# 🔧 Loading XVECTOR baseline...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# 🔍 Extracting embeddings...
# Extracting embeddings: 100%|█████████████████| 542/542 [00:03<00:00, 152.07it/s]
# Extracted 8662 embeddings, dim=512
# Creating impostor trials: 100%|████████| 20380/20380 [00:00<00:00, 36282.07it/s]
#
# ============================================================
# 📈 BASELINE (XVECTOR) RESULTS
# ============================================================
# Overall EER: 25.72%
#
# --- Per-Language EER ---
# Tamil EER: 22.09%
# Telugu EER: 26.85%
# English EER: 29.15%
# ============================================================
