# %%
# !python wavlmraw.py --config 5percent --split 1
# Out:
# ...
# 📊 EVALUATING RAW WAVLM (NO FINE-TUNING)
# ...
# Dataset: 5percent
# Split: 1 (Identification)
# Model: WavLM-Large (Frozen, No Fine-tuning)
# Batch size: 32
# Max trials: 50000
#
# 📂 Loading test dataset...
# 📊 HD-SIN Dataset: 13983 files
#    Speakers: 6171
#    Languages: {'telugu', 'tamil', 'english'}
#
# 🔧 Loading Raw WavLM (No Fine-tuning)...
#    Device: cuda:0
# 🔄 Loading raw WavLM-large (no fine-tuning, frozen)...
# Loading weights: 100%|█| 488/488 [00:00<00:00, 13739.54it/s, Materializing param
# ✅ Raw WavLM loaded, hidden size: 1024
#
# 🔍 Extracting embeddings...
# Extracting embeddings: 100%|██████████████████| 437/437 [06:06<00:00,  1.19it/s]
#
# ✅ Extracted 13983 embeddings, dim=1024
#
# 📊 Grouping by speaker...
#    Unique speakers: 6171
#
# 📊 Creating evaluation trials...
#    Creating genuine trials...
#    Genuine trials: 91251
#    Creating impostor trials...
#    Creating impostor trials: 100%|█████| 50000/50000 [00:03<00:00, 15777.37it/s]
#    Impostor trials: 50000
#
# ...

# %%
# !python wavlmraw.py --config 5percent --split 2
# Out:
# ...
# 📊 EVALUATING RAW WAVLM (NO FINE-TUNING)
# ...
# Dataset: 5percent
# Split: 2 (Open-set)
# Model: WavLM-Large (Frozen, No Fine-tuning)
# Batch size: 32
# Max trials: 50000
#
# 📂 Loading test dataset...
# 📊 HD-SIN Dataset: 8662 files
#    Speakers: 1019
#    Languages: {'tamil', 'english', 'telugu'}
#
# 🔧 Loading Raw WavLM (No Fine-tuning)...
#    Device: cuda:0
# 🔄 Loading raw WavLM-large (no fine-tuning, frozen)...
# Loading weights: 100%|█| 488/488 [00:00<00:00, 14430.08it/s, Materializing param
# ✅ Raw WavLM loaded, hidden size: 1024
#
# 🔍 Extracting embeddings...
# Extracting embeddings: 100%|██████████████████| 271/271 [03:49<00:00,  1.18it/s]
#
# ✅ Extracted 8662 embeddings, dim=1024
#
# 📊 Grouping by speaker...
#    Unique speakers: 1019
#
# 📊 Creating evaluation trials...
#    Creating genuine trials...
#    Genuine trials: 64315
#    Creating impostor trials...
#    Creating impostor trials: 100%|█████| 50000/50000 [00:01<00:00, 34233.91it/s]
#    Impostor trials: 50000
#
# ...
