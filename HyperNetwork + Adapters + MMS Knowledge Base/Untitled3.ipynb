# %%
# HuBERT Raw Split 1
# !python evaluate_hubert_raw.py --config 5percent --split 1
# Out:
# ======================================================================
# 📊 EVALUATING RAW HUBERT (NO FINE-TUNING)
# ======================================================================
# Dataset: 5percent
# Split: 1 (Identification)
# Model: HuBERT-Large (Frozen, No Fine-tuning)
# Batch size: 32
#
# 📂 Loading test dataset...
# 📊 HD-SIN Dataset: 13983 files
#    Speakers: 6171
#    Languages: {'english', 'tamil', 'telugu'}
#
# 🔧 Loading Raw HuBERT...
#    Device: cuda:0
# 🔄 Loading raw HuBERT-large (no fine-tuning, frozen)...
# config.json: 1.38kB [00:00, 76.8kB/s]
# pytorch_model.bin: 100%|███████████████████| 1.26G/1.26G [01:25<00:00, 14.8MB/s]
# Loading weights: 100%|█| 422/422 [00:00<00:00, 13890.39it/s, Materializing param
# HubertModel LOAD REPORT from: facebook/hubert-large-ls960-ft
# Key            | Status     |  |
# ---------------+------------+--+-
# lm_head.bias   | UNEXPECTED |  |
# lm_head.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ Raw HuBERT loaded, hidden size: 1024
#
# 🔍 Extracting embeddings...
# Extracting embeddings:   1%|▏                   | 3/437 [00:01<04:11,  1.72it/s]
# Extracting embeddings:   3%|▍                  | 11/437 [00:06<03:46,  1.88it/s]
# Extracting embeddings:   8%|█▌                 | 36/437 [00:19<03:35,  1.86it/s]
# Extracting embeddings:  11%|██▏                | 49/437 [00:26<03:29,  1.85it/s]
# Extracting embeddings:  17%|███▏               | 73/437 [00:39<03:17,  1.84it/s]
# Extracting embeddings:  27%|████▊             | 117/437 [01:03<02:55,  1.82it/s]
# Extracting embeddings:  30%|█████▍            | 131/437 [01:11<02:48,  1.82it/s]
# Extracting embeddings:  31%|█████▌            | 136/437 [01:13<02:45,  1.82it/s]
# Extracting embeddings:  33%|██████            | 146/437 [01:19<02:39,  1.82it/s]
# model.safetensors:  26%|█████▏              | 324M/1.26G [01:17<02:32, 6.15MB/s]
# Extracting embeddings:  34%|██████            | 147/437 [01:19<02:39,  1.82it/s]
# Extracting embeddings:  34%|██████▏           | 149/437 [01:21<02:38,  1.82it/s]
# Extracting embeddings:  34%|██████▏           | 150/437 [01:21<02:38,  1.81it/s]
# Extracting embeddings:  35%|██████▏           | 151/437 [01:22<02:37,  1.81it/s]
# Extracting embeddings:  35%|██████▎           | 152/437 [01:22<02:37,  1.81it/s]
# Extracting embeddings:  35%|██████▎           | 153/437 [01:23<02:36,  1.81it/s]
# Extracting embeddings:  36%|██████▍           | 156/437 [01:24<02:34,  1.81it/s]
# Extracting embeddings:  36%|██████▌           | 159/437 [01:26<02:33,  1.82it/s]
# Extracting embeddings:  37%|██████▌           | 160/437 [01:27<02:32,  1.81it/s]
# model.safetensors: 100%|███████████████████| 1.26G/1.26G [01:25<00:00, 14.7MB/s]
# Extracting embeddings: 100%|██████████████████| 437/437 [03:59<00:00,  1.82it/s]
#
# ✅ Extracted 13983 embeddings, dim=1024
#
# 📊 Grouping by speaker...
#    Unique speakers: 6171
#
# 📊 Creating evaluation trials...
#    Creating genuine trials...
#    Genuine trials: 91251
#    Creating impostor trials...
#    Creating impostor trials: 100%|█████| 50000/50000 [00:03<00:00, 15061.42it/s]
#    Impostor trials: 50000
#
# 📊 Computing results...
#
# ======================================================================
# 📈 HuBERT-Large (Raw, No Fine-tuning) RESULTS
# ======================================================================
#
# =================Overall Results==================
# Equal Error Rate (EER): 38.84%
# Area Under Curve (AUC): 0.6578
# Threshold at EER: 0.9671
#
# Genuine scores: mean=0.9667 ± 0.0225
# Impostor scores: mean=0.9338 ± 0.0589
#
# ===============Per-Language Results===============
#
# Tamil:
#   EER: 43.43%
#   AUC: 0.5952
#   Genuine mean: 0.9725
#   Impostor mean: 0.9642
#
# Telugu:
#   EER: 37.64%
#   AUC: 0.6771
#   Genuine mean: 0.9617
#   Impostor mean: 0.9359
#
# English:
#   EER: 42.66%
#   AUC: 0.6020
#   Genuine mean: 0.9670
#   Impostor mean: 0.9570
#
# ✅ Results saved to: ./hubert_raw_split1_results.txt
#
# 📊 Generating plots...
# ✅ Plot saved to: ./hubert_raw_split1_results.png
#
# ======================================================================
# 📊 FINAL SUMMARY - RAW HUBERT
# ======================================================================
# Split: 1
# EER: 38.84%
# AUC: 0.6578

# %%
# HuBERT Raw Split 1
# !python evaluate_hubert_raw.py --config 5percent --split 2
# Out:
# ======================================================================
# 📊 EVALUATING RAW HUBERT (NO FINE-TUNING)
# ======================================================================
# Dataset: 5percent
# Split: 2 (Open-set)
# Model: HuBERT-Large (Frozen, No Fine-tuning)
# Batch size: 32
#
# 📂 Loading test dataset...
# 📊 HD-SIN Dataset: 8662 files
#    Speakers: 1019
#    Languages: {'tamil', 'telugu', 'english'}
#
# 🔧 Loading Raw HuBERT...
#    Device: cuda:0
# 🔄 Loading raw HuBERT-large (no fine-tuning, frozen)...
# Loading weights: 100%|█| 422/422 [00:00<00:00, 14262.78it/s, Materializing param
# HubertModel LOAD REPORT from: facebook/hubert-large-ls960-ft
# Key            | Status     |  |
# ---------------+------------+--+-
# lm_head.weight | UNEXPECTED |  |
# lm_head.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ Raw HuBERT loaded, hidden size: 1024
#
# 🔍 Extracting embeddings...
# Extracting embeddings: 100%|██████████████████| 271/271 [02:28<00:00,  1.82it/s]
#
# ✅ Extracted 8662 embeddings, dim=1024
#
# 📊 Grouping by speaker...
#    Unique speakers: 1019
#
# 📊 Creating evaluation trials...
#    Creating genuine trials...
#    Genuine trials: 64315
#    Creating impostor trials...
#    Creating impostor trials: 100%|█████| 50000/50000 [00:01<00:00, 35628.54it/s]
#    Impostor trials: 50000
#
# 📊 Computing results...
#
# ======================================================================
# 📈 HuBERT-Large (Raw, No Fine-tuning) RESULTS
# ======================================================================
#
# =================Overall Results==================
# Equal Error Rate (EER): 34.72%
# Area Under Curve (AUC): 0.7179
# Threshold at EER: 0.9674
#
# Genuine scores: mean=0.9675 ± 0.0287
# Impostor scores: mean=0.9282 ± 0.0610
#
# ===============Per-Language Results===============
#
# Tamil:
#   EER: 41.74%
#   AUC: 0.6243
#   Genuine mean: 0.9742
#   Impostor mean: 0.9618
#
# Telugu:
#   EER: 38.20%
#   AUC: 0.6708
#   Genuine mean: 0.9605
#   Impostor mean: 0.9373
#
# English:
#   EER: 41.22%
#   AUC: 0.6237
#   Genuine mean: 0.9675
#   Impostor mean: 0.9565
#
# ✅ Results saved to: ./hubert_raw_split2_results.txt
#
# 📊 Generating plots...
