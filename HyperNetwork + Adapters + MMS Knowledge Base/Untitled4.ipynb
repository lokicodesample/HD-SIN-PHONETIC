# %%
# Evaluate Tamil with IndicWav2Vec
python evaluate_indicwav2vec.py --config 5percent --split 1 --language tamil

# Evaluate Telugu with IndicWav2Vec
python evaluate_indicwav2vec.py --config 5percent --split 1 --language telugu

# Evaluate English with Wav2Vec2 (fallback)
python evaluate_indicwav2vec.py --config 5percent --split 1 --language english

# For Split 2 (open-set)
python evaluate_indicwav2vec.py --config 5percent --split 2 --language tamil
python evaluate_indicwav2vec.py --config 5percent --split 2 --language telugu

# %%
# Evaluate Tamil with IndicWav2Vec
# !python Evaluate_indicwav2vec_2L.py --config 5percent --split 1 --language tamil
# Out:
# ...
# 📊 EVALUATING INDICWAV2VEC (TAMIL)
# ...
# Dataset: 5percent
# Split: 1 (Identification)
# Language: tamil
# Batch size: 32
#
# 📂 Loading test dataset...
# 📊 HD-SIN Dataset: 13983 files
#    Speakers: 6171
#    Languages: {'tamil', 'telugu', 'english'}
#
# 🔧 Loading IndicWav2Vec model for tamil...
#    Device: cuda:0
# 🔄 Loading ai4bharat/indicwav2vec for tamil...
# ⚠️ Falling back to Wav2Vec2-large...
# Loading weights: 100%|█| 404/404 [00:00<00:00, 13444.03it/s, Materializing param
# Wav2Vec2ForCTC LOAD REPORT from: facebook/wav2vec2-large-960h
# Key                        | Status  |
# ---------------------------+---------+-
# wav2vec2.masked_spec_embed | MISSING |
#
# Notes:
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# ✅ Model loaded, hidden size: 1024
#
# 🔍 Extracting embeddings...
# Extracting embeddings: 100%|██████████████████| 437/437 [03:40<00:00,  1.98it/s]
#
# ...

# %%
# Evaluate Telugu with IndicWav2Vec
# !python Evaluate_indicwav2vec_2L.py --config 5percent --split 1 --language telugu
# Out:
# ...
# 📊 EVALUATING INDICWAV2VEC (TELUGU)
# ...
# Dataset: 5percent
# Split: 1 (Identification)
# Language: telugu
# Batch size: 32
#
# 📂 Loading test dataset...
# 📊 HD-SIN Dataset: 13983 files
#    Speakers: 6171
#    Languages: {'english', 'telugu', 'tamil'}
#
# 🔧 Loading IndicWav2Vec model for telugu...
#    Device: cuda:0
# 🔄 Loading ai4bharat/indicwav2vec for telugu...
# ⚠️ Falling back to Wav2Vec2-large...
# Loading weights: 100%|█| 404/404 [00:00<00:00, 13854.47it/s, Materializing param
# Wav2Vec2ForCTC LOAD REPORT from: facebook/wav2vec2-large-960h
# Key                        | Status  |
# ---------------------------+---------+-
# wav2vec2.masked_spec_embed | MISSING |
#
# Notes:
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# ✅ Model loaded, hidden size: 1024
#
# 🔍 Extracting embeddings...
# Extracting embeddings: 100%|██████████████████| 437/437 [03:42<00:00,  1.96it/s]
#
# ...

# %%
# Evaluate English with Wav2Vec2 (fallback)
# !python Evaluate_indicwav2vec_2L.py --config 5percent --split 1 --language english
# Out:
# ...
# 📊 EVALUATING INDICWAV2VEC (ENGLISH)
# ...
# Dataset: 5percent
# Split: 1 (Identification)
# Language: english
# Batch size: 32
#
# 📂 Loading test dataset...
# 📊 HD-SIN Dataset: 13983 files
#    Speakers: 6171
#    Languages: {'telugu', 'tamil', 'english'}
#
# 🔧 Loading IndicWav2Vec model for english...
#    Device: cuda:0
# 🔄 Loading ai4bharat/indicwav2vec for english...
# ⚠️ Falling back to Wav2Vec2-large...
# Loading weights: 100%|█| 404/404 [00:00<00:00, 13835.92it/s, Materializing param
# Wav2Vec2ForCTC LOAD REPORT from: facebook/wav2vec2-large-960h
# Key                        | Status  |
# ---------------------------+---------+-
# wav2vec2.masked_spec_embed | MISSING |
#
# Notes:
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# ✅ Model loaded, hidden size: 1024
#
# 🔍 Extracting embeddings...
# Extracting embeddings: 100%|██████████████████| 437/437 [03:41<00:00,  1.98it/s]
#
# ...

# %%
# For Split 2 (open-set)
# !python Evaluate_indicwav2vec_2L.py --config 5percent --split 2 --language tamil
# Out:
# ...
# 📊 EVALUATING INDICWAV2VEC (TAMIL)
# ...
# Dataset: 5percent
# Split: 2 (Open-set)
# Language: tamil
# Batch size: 32
#
# 📂 Loading test dataset...
# 📊 HD-SIN Dataset: 8662 files
#    Speakers: 1019
#    Languages: {'telugu', 'english', 'tamil'}
#
# 🔧 Loading IndicWav2Vec model for tamil...
#    Device: cuda:0
# 🔄 Loading ai4bharat/indicwav2vec for tamil...
# ⚠️ Falling back to Wav2Vec2-large...
# Loading weights: 100%|█| 404/404 [00:00<00:00, 13029.49it/s, Materializing param
# Wav2Vec2ForCTC LOAD REPORT from: facebook/wav2vec2-large-960h
# Key                        | Status  |
# ---------------------------+---------+-
# wav2vec2.masked_spec_embed | MISSING |
#
# Notes:
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# ✅ Model loaded, hidden size: 1024
#
# 🔍 Extracting embeddings...
# Extracting embeddings: 100%|██████████████████| 271/271 [02:16<00:00,  1.98it/s]
#
# ✅ Extracted 8662 embeddings, dim=1024
#
# ...

# %%
# !python Evaluate_indicwav2vec_2L.py --config 5percent --split 2 --language telugu
# Out:
# ...
# 📊 EVALUATING INDICWAV2VEC (TELUGU)
# ...
# Dataset: 5percent
# Split: 2 (Open-set)
# Language: telugu
# Batch size: 32
#
# 📂 Loading test dataset...
# 📊 HD-SIN Dataset: 8662 files
#    Speakers: 1019
#    Languages: {'english', 'tamil', 'telugu'}
#
# 🔧 Loading IndicWav2Vec model for telugu...
#    Device: cuda:0
# 🔄 Loading ai4bharat/indicwav2vec for telugu...
# ⚠️ Falling back to Wav2Vec2-large...
# Loading weights: 100%|█| 404/404 [00:00<00:00, 13756.84it/s, Materializing param
# Wav2Vec2ForCTC LOAD REPORT from: facebook/wav2vec2-large-960h
# Key                        | Status  |
# ---------------------------+---------+-
# wav2vec2.masked_spec_embed | MISSING |
#
# Notes:
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# ✅ Model loaded, hidden size: 1024
#
# 🔍 Extracting embeddings...
# Extracting embeddings: 100%|██████████████████| 271/271 [02:17<00:00,  1.97it/s]
#
# ...

# %%
# Evaluate English with Wav2Vec2 (fallback)
# !python Evaluate_indicwav2vec_2L.py --config 5percent --split 2 --language english
# Out:
# ...
# 📊 EVALUATING INDICWAV2VEC (ENGLISH)
# ...
# Dataset: 5percent
# Split: 2 (Open-set)
# Language: english
# Batch size: 32
#
# 📂 Loading test dataset...
# 📊 HD-SIN Dataset: 8662 files
#    Speakers: 1019
#    Languages: {'tamil', 'telugu', 'english'}
#
# 🔧 Loading IndicWav2Vec model for english...
#    Device: cuda:0
# 🔄 Loading ai4bharat/indicwav2vec for english...
# ⚠️ Falling back to Wav2Vec2-large...
# Loading weights: 100%|█| 404/404 [00:00<00:00, 13652.10it/s, Materializing param
# Wav2Vec2ForCTC LOAD REPORT from: facebook/wav2vec2-large-960h
# Key                        | Status  |
# ---------------------------+---------+-
# wav2vec2.masked_spec_embed | MISSING |
#
# Notes:
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# ✅ Model loaded, hidden size: 1024
#
# 🔍 Extracting embeddings...
# Extracting embeddings: 100%|██████████████████| 271/271 [02:17<00:00,  1.97it/s]
#
# ...
