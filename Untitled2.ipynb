# %%
# Train all architectures
# !python train.py --arch all
# Out:
# ...
# 🎯 BASELINE ARCHITECTURES TRAINING
# ...
# Device: cuda
# GPU: NVIDIA RTX A6000
# GPU Memory: 50.9 GB
# Batch size: 64
# Mixed precision: True
# Epochs: 20
# Resume: False
#
# 📂 Creating dataloaders...
# 📊 Dataset loaded: 879822 files, 10914 speakers
# 📊 Dataset loaded: 189774 files, 10914 speakers
# 📊 Triplet dataset: 879822 files, 10914 speakers
# 🔄 Loading WavLM-large (frozen)...
# Loading weights: 100%|█| 488/488 [00:00<00:00, 14166.61it/s, Materializing param
# ✅ Architecture A: 6,329,419 trainable params
# /home/ladmin/new_env_nemo/my_local_data/processed_dataset/manifests/train.py:86: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler(enabled=config.USE_AMP)
#
# 🚀 Training Architecture A (Classifier)
# ...
# Starting from epoch 1/20
# Batch size: 64, Mixed Precision: True
# ...

# %%
# Train only Architecture A
# !python train.py --arch a
# Out:
# ...
# 🎯 BASELINE ARCHITECTURES TRAINING
# ...
# Device: cuda
# GPU: NVIDIA RTX A6000
# GPU Memory: 50.9 GB
# Batch size: 48
# Mixed precision: True
# Epochs: 5
# Resume: False
#
# 📂 Creating dataloaders...
# 📊 Dataset loaded: 879822 files, 10914 speakers
# 📊 Dataset loaded: 189774 files, 10914 speakers
# 📊 Triplet dataset: 879822 files, 10914 speakers
# 🔄 Loading WavLM-large (frozen)...
# Loading weights: 100%|█| 488/488 [00:00<00:00, 14200.72it/s, Materializing param
# ✅ Architecture A: 6,329,419 trainable params
# /home/ladmin/new_env_nemo/my_local_data/processed_dataset/manifests/train.py:86: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler(enabled=config.USE_AMP)
#
# 🚀 Training Architecture A (Classifier)
# ...
# Starting from epoch 1/5
# Batch size: 48, Mixed Precision: True
# ...

# %%
# Train only Architecture B  
python train.py --arch b
# Out:
#   Cell In[9], line 2
#     python train.py --arch b
#            ^
# SyntaxError: invalid syntax

# %%
# Train only Architecture C
python train.py --arch c
