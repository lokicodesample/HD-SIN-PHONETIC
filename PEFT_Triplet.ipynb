# %%
# Terminal 2 - Architecture B Split 1  
python architecture_b.py --config 5percent --split 1 --epochs 10 --batch_size 64 --auto_resume
python architecture_b.py --config 5percent --split 2 --epochs 10 --batch_size 64 --auto_resume

# %%
# !python architecture_b.py --config 5percent --split 1 --epochs 10 --batch_size 8 --auto_resume

# %%
# Architecture B
python evaluate_b.py --config 5percent --split 1 --checkpoint checkpoints/architecture_b_split1_best.pt
python evaluate_b.py --config 5percent --split 2 --checkpoint checkpoints/architecture_b_split2_best.pt
