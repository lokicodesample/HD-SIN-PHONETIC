# %%
# Terminal 3 - Architecture C Split 1
python architecture_c.py --config 5percent --split 1 --epochs 10 --batch_size 64 --auto_resume
python architecture_c.py --config 5percent --split 2 --epochs 10 --batch_size 64 --auto_resume

# %%
# !python architecture_c.py --config 5percent --split 1 --epochs 10 --batch_size 16 --auto_resume
# Out:
# ...
# 🎯 ARCHITECTURE C: Full Model Fine-tuning
# ...
# Dataset: 5percent
# Split: 1
# Batch size: 16
# Epochs: 10
# Auto-resume: True
#
# 📂 Loading dataset...
# 📊 Triplet dataset: 62521 files, 7919 valid speakers
# 🔄 Loading WavLM-large (partially frozen)...
# Loading weights: 100%|█| 488/488 [00:00<00:00, 14284.96it/s, Materializing param
#    Unfroze top 3 of 24 layers
# ✅ Architecture C: 38,052,680/315,715,520 trainable (12.05%)
# 📂 Found checkpoint: checkpoints/architecture_c_split1_checkpoint.pt
# ✅ Resumed from epoch 4
# Epoch 5/10 [Train]:   0%|       | 2/9899 [00:03<4:05:56,  1.49s/it, loss=0.3515]^C
#
#
# ⚠️  Interrupt received! Saving checkpoint before exit...
#
# ⚠️  Interrupt received! Saving checkpoint before exit...
#
#
#
# ⚠️  Interrupt received! Saving checkpoint before exit...
#
#
# ⚠️  Interrupt received! Saving checkpoint before exit...
#
#
# ⚠️  Interrupt received! Saving checkpoint before exit...
#
# ⚠️  Interrupt received! Saving checkpoint before exit...
#
#
#
# ...

# %%
# Architecture C
# !python Evaluate_Full_Fine-tune.py --config 5percent --split 1 --checkpoint checkpoints/architecture_c_split1_best.pt
# Out:
# ...
# 📊 EVALUATING ARCHITECTURE C
# ...
# Dataset: 5percent
# Split: 1
# Checkpoint: checkpoints/architecture_c_split1_best.pt
#
# 📂 Loading test dataset...
#
# 🔧 Loading model...
# 🔄 Loading WavLM-large (partially frozen)...
# Loading weights: 100%|█| 488/488 [00:00<00:00, 14340.00it/s, Materializing param
#    Unfroze top 3 of 24 layers
# ✅ Architecture C: 38,052,680/315,715,520 trainable (12.05%)
#
# 🔍 Extracting embeddings...
# Extracting: 100%|█████████████████████████████| 437/437 [05:53<00:00,  1.24it/s]
# ✅ Extracted 13983 embeddings, dim=256
#
# 📊 Creating evaluation trials...

# %%
# Architecture C
# !python Evaluate_Full_Fine-tune.py --config 5percent --split 1 --checkpoint checkpoints/architecture_c_split1_best.pt
# Out:
# ...
# 📊 EVALUATING ARCHITECTURE C
# ...
# Dataset: 5percent
# Split: 1
# Checkpoint: checkpoints/architecture_c_split1_best.pt
# Batch size: 32
#
# 📂 Loading test dataset...
#    Loaded 13983 files
#
# 🔧 Loading model...
# 🔄 Loading WavLM-large (partially frozen)...
# Loading weights: 100%|█| 488/488 [00:00<00:00, 13948.05it/s, Materializing param
#    Unfroze top 3 of 24 layers
# ✅ Architecture C: 38,052,680/315,715,520 trainable (12.05%)
#    Loaded model weights
#
# 🔍 Extracting embeddings...
# ...
# Extracting: 100%|█████████████████████████████| 437/437 [05:52<00:00,  1.24it/s]
# ✅ Extracted 13983 embeddings, dim=256
#    Time taken: 352.3s
#
# 📊 Grouping by speaker...
#    Unique speakers: 6171
#
# 📊 Creating evaluation trials...
#    Creating genuine trials...
#    Genuine trials: 43054
#    Creating impostor trials...
#    Creating impostor trials: 100%|██████| 50000/50000 [00:46<00:00, 1079.52it/s]
#    Impostor trials: 50000
#
# 📊 Computing EER and AUC...
#
# 📈 RESULTS:
# ...
#    EER: 8.02%
# ...

# %%
# !python Evaluate_Full_Fine-tune.py --config 5percent --split 2 --checkpoint checkpoints/architecture_c_split1_best.pt
# Out:
# ...
# 📊 EVALUATING ARCHITECTURE C
# ...
# Dataset: 5percent
# Split: 2
# Checkpoint: checkpoints/architecture_c_split1_best.pt
# Batch size: 32
#
# 📂 Loading test dataset...
#    Loaded 8662 files
#
# 🔧 Loading model...
# 🔄 Loading WavLM-large (partially frozen)...
# Loading weights: 100%|█| 488/488 [00:00<00:00, 14383.03it/s, Materializing param
#    Unfroze top 3 of 24 layers
# ✅ Architecture C: 38,052,680/315,715,520 trainable (12.05%)
#    Loaded model weights
#
# 🔍 Extracting embeddings...
# ...
# Extracting: 100%|█████████████████████████████| 271/271 [03:39<00:00,  1.23it/s]
# ✅ Extracted 8662 embeddings, dim=256
#    Time taken: 219.5s
#
# 📊 Grouping by speaker...
#    Unique speakers: 1019
#
# 📊 Creating evaluation trials...
#    Creating genuine trials...
#    Genuine trials: 45006
#    Creating impostor trials...
#    Creating impostor trials: 100%|██████| 50000/50000 [00:08<00:00, 5968.43it/s]
#    Impostor trials: 50000
#
# 📊 Computing EER and AUC...
#
# 📈 RESULTS:
# ...
#    EER: 8.71%
# ...

# %%
# !python Evaluate_Full_Fine-tune.py --config 5percent --split 1 --checkpoint checkpoints/architecture_c_split1_best.pt
# Out:
# ...
# 📊 EVALUATING ARCHITECTURE C
# ...
# Dataset: 5percent
# Split: 1
# Checkpoint: checkpoints/architecture_c_split1_best.pt
#
# 📂 Loading test dataset...
#    Loaded 13983 files
#
# 🔧 Loading model...
# 🔄 Loading WavLM-large (partially frozen)...
# Loading weights: 100%|█| 488/488 [00:00<00:00, 14001.67it/s, Materializing param
#    Unfroze top 3 of 24 layers
# ✅ Architecture C: 38,052,680/315,715,520 trainable (12.05%)
#
# 🔍 Extracting embeddings...
# Extracting: 100%|█████████████████████████████| 437/437 [05:52<00:00,  1.24it/s]
# ✅ Extracted 13983 embeddings, dim=256
#    Unique speakers: 6171
#    Languages: ['telugu', 'tamil', 'english']
#
# 📊 Creating evaluation trials...
# Creating impostor trials: 100%|█████████| 50000/50000 [00:46<00:00, 1067.56it/s]
#
# 📈 OVERALL RESULTS:
# ...
#    EER: 8.01%
#    AUC: 0.9741
#    Genuine scores: 0.9556 ± 0.0861
#    Impostor scores: 0.0193 ± 0.5029
# ...
#
# 📈 PER-LANGUAGE RESULTS:
#
#    Tamil:
#       EER: 1.92%
#       Genuine mean: 0.9438
# ...

# %%
# !python Evaluate_Full_Fine-tune.py --config 5percent --split 2 --checkpoint checkpoints/architecture_c_split1_best.pt
# Out:
# ...
# 📊 EVALUATING ARCHITECTURE C
# ...
# Dataset: 5percent
# Split: 2
# Checkpoint: checkpoints/architecture_c_split1_best.pt
#
# 📂 Loading test dataset...
#    Loaded 8662 files
#
# 🔧 Loading model...
# 🔄 Loading WavLM-large (partially frozen)...
# Loading weights: 100%|█| 488/488 [00:00<00:00, 13697.15it/s, Materializing param
#    Unfroze top 3 of 24 layers
# ✅ Architecture C: 38,052,680/315,715,520 trainable (12.05%)
#
# 🔍 Extracting embeddings...
# Extracting: 100%|█████████████████████████████| 271/271 [03:39<00:00,  1.23it/s]
# ✅ Extracted 8662 embeddings, dim=256
#    Unique speakers: 1019
#    Languages: ['telugu', 'tamil', 'english']
#
# 📊 Creating evaluation trials...
# Creating impostor trials: 100%|█████████| 50000/50000 [00:08<00:00, 5998.77it/s]
#
# 📈 OVERALL RESULTS:
# ...
#    EER: 8.81%
#    AUC: 0.9699
#    Genuine scores: 0.9451 ± 0.1000
#    Impostor scores: 0.0058 ± 0.4996
# ...
#
# 📈 PER-LANGUAGE RESULTS:
#
#    Tamil:
#       EER: 1.90%
#       Genuine mean: 0.9415
# ...

# %%
# Architecture C
python evaluate_c.py --config 5percent --split 1 --checkpoint checkpoints/architecture_c_split1_best.pt
python evaluate_c.py --config 5percent --split 2 --checkpoint checkpoints/architecture_c_split1_best.pt
