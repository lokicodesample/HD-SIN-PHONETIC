# %%
# Terminal 1
python architecture_a.py --config 5percent --epochs 2

# Terminal 2
python architecture_b.py --config 5percent --epochs 2

# Terminal 3
python architecture_c.py --config 5percent --epochs 2

# %%
# Terminal 1
# !python architecture_a.py --config 5percent --epochs 10 --auto_resume
# Out:
# usage: architecture_a.py [-h] --config {5percent,50percent} --split {1,2}
#                          [--epochs EPOCHS] [--batch_size BATCH_SIZE]
#                          [--resume] [--auto_resume]
# architecture_a.py: error: the following arguments are required: --split

# %%
# Terminal 2
# !python architecture_b.py --config 5percent --epochs 2
# Out:
# ...
# 🎯 ARCHITECTURE B: PEFT Metric Learning
# ...
# Dataset: 5percent
# Device: cuda
# Batch size: 16
# Epochs: 2
#
# 📂 Loading dataset...
# 📊 Triplet dataset: 62521 files, 7919 valid speakers
# 🔄 Loading WavLM-large (frozen)...
# ✅ Architecture B: 262,424 trainable params
# Epoch 1/2 [Train]:   0%|       | 14/9899 [00:19<3:52:37,  1.41s/it, loss=0.9125]^C

# %%
# Terminal 3
# !python architecture_c.py --config 5percent --epochs 2
# Out:
# ...
# 🎯 ARCHITECTURE C: Full Model Fine-tuning
# ...
# Dataset: 5percent
# Device: cuda
# Batch size: 16
# Epochs: 2
#
# 📂 Loading dataset...
# 📊 Triplet dataset: 62521 files, 7919 valid speakers
# 🔄 Loading WavLM-large (partially frozen)...
#    Unfroze top 3 of 24 layers
# ✅ Architecture C: 38,052,680/315,715,520 trainable (12.05%)
# ...
# Epoch 1/2 [Train]:   0%|       | 11/9899 [00:15<3:53:33,  1.42s/it, loss=0.4930]
# Traceback (most recent call last):
#   File "/home/ladmin/new_env_nemo/my_local_data/processed_dataset/manifests/architecture_c.py", line 200, in <module>
#     train()
#   File "/home/ladmin/new_env_nemo/my_local_data/processed_dataset/manifests/architecture_c.py", line 161, in train
#     positive_emb = model(positive)
#                    ^^^^^^^^^^^^^^^
#   File "/home/ladmin/.local/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
